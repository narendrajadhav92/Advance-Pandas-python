# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## pd.read_csv('file/ location')
# ### pd.read_csv('file/ location', index_col = "col_name")

# %%
df = pd.read_csv('s_public.csv', index_col = 'Respondent')
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ## df.shape

# %%
df.shape
# Out:
# (88883, 84)

# %% [markdown]
# ### pd.set_option('display.max_columns' ,20  )

# %%
pd.set_option('display.max_columns',85)

# %%
df.loc[1]
# Out:
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                 Not employed, and not looking for work
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 84, dtype: object

# %%
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column' )
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc['SocialMedia', 'QuestionText']
# Out:
# 'What social media site do you use the most?'

# %% [markdown]
# ### df.sort_index(ascending = True)

# %%
schema_df.sort_index(ascending = True)
schema_df.sort_index(inplace = True)
schema_df
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
people = {
    'first' : ['Corey', 'Jane' , 'john'],
    'last' :['Schafer', "Doe", "Carter"],
    'email' : ['corescha_00@gmail.com' , 'JanaDn_11@gmail.com', 'Johncat_22@gmail.com']
}
df_pl = pd.DataFrame(people)
df_pl
# Out:
#    first     last                  email
# 0  Corey  Schafer  corescha_00@gmail.com
# 1   Jane      Doe    JanaDn_11@gmail.com
# 2   john   Carter   Johncat_22@gmail.com

# %%
# series = single column of rows
type(df_pl['email'])
# Out:
# pandas.core.series.Series

# %%
df_pl.email
# Out:
# 0    corescha_00@gmail.com
# 1      JanaDn_11@gmail.com
# 2     Johncat_22@gmail.com
# Name: email, dtype: object

# %%
df_pl[['last', 'email']]
# Out:
#       last                  email
# 0  Schafer  corescha_00@gmail.com
# 1      Doe    JanaDn_11@gmail.com
# 2   Carter   Johncat_22@gmail.com

# %% [markdown]
# ## df.columns

# %%
# will return columns name list
df_pl.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ## df.iloc[0]
# to return rows at given index
# ### df.iloc[ [rows]  , [ columns] ]

# %%
df_pl.iloc[0]
# to get two rows of data
df_pl.iloc[[1,0],[1,0]]
# Out:
#       last  first
# 1      Doe   Jane
# 0  Schafer  Corey

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'F', 'F'],
    'favourite_color' : [ 'red', np.NAN, 'yellow', np.NAN, 'black', 'green', 'red']
})

# view the data
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      F           green
# 6   17       A   Mumbai      F             red

# %%
# select all rows with a condition
data.loc[data.age >= 15]
# Out:
#    age section    city gender favourite_color
# 1   22       B   Delhi      F             NaN
# 3   21       B   Delhi      M             NaN
# 6   17       A  Mumbai      F             red

# %%
# select with multiple conditions
data.loc[(data.age >= 12) | (data.gender == 'M')]
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 6   17       A   Mumbai      F             red

# %%
# slice 
# cannot slice if indices are not numbers
data.loc[1:3]
# Out:
#    age section    city gender favourite_color
# 1   22       B   Delhi      F             NaN
# 2   13       C  Mumbai      F          yellow
# 3   21       B   Delhi      M             NaN

# %% [markdown]
# Select only required columns with a condition

# %%
# select few columns with a condition
data.loc[(data.age >= 12 ), ['city', 'gender']]
# Out:
#      city gender
# 1   Delhi      F
# 2  Mumbai      F
# 3   Delhi      M
# 4  Mumbai      M
# 6  Mumbai      F

# %% [markdown]
# Update the values

# %%
# update a column with condition
data.loc[(data.age >= 12), ['section']] = 'M'
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       M    Delhi      F             NaN
# 2   13       M   Mumbai      F          yellow
# 3   21       M    Delhi      M             NaN
# 4   12       M   Mumbai      M           black
# 5   11       A    Delhi      F           green
# 6   17       M   Mumbai      F             red

# %%
# update multiple columns with condition
data.loc[(data.age >= 20), ['section', 'city']] = ['S','Pune']
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       S     Pune      F             NaN
# 2   13       M   Mumbai      F          yellow
# 3   21       S     Pune      M             NaN
# 4   12       M   Mumbai      M           black
# 5   11       A    Delhi      F           green
# 6   17       M   Mumbai      F             red

# %%
# select a range of rows+
data.iloc[1:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10452\1467596088.py in <module>
#       1 # select a range of rows+
# ----> 2 data.iloc[1:3]
#
# NameError: name 'data' is not defined

# %%
# select a range of rows and columns
data.iloc[1:3,2:4]
# Out:
#      city gender
# 1    Pune      F
# 2  Mumbai      F

# %%
df.loc[:5, 'Hobbyist':'Country' ]
# Out:
#            Hobbyist                 OpenSourcer  \
# Respondent
# 1               Yes                       Never
# 2                No     Less than once per year
# 3               Yes                       Never
# 4                No                       Never
# 5               Yes  Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# ...

# %% [markdown]
# ## df['column name' ].value_counts()

# %%
# To calculate unique values count
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
# to see unique value list
df['YearsCode'].unique()
# Out:
# array([ 4., nan,  3., 16., 13.,  6.,  8., 12.,  2.,  5., 17., 10., 14.,
#        35.,  7.,  0., 30.,  9., 26., 40., 19., 15., 20., 28., 25.,  1.,
#        22., 11., 33., 50., 41., 18., 34., 24., 23., 42., 27., 21., 36.,
#        32., 39., 38., 31., 37., 29., 44., 45., 48., 46., 43., 47., 49.])

# %% [markdown]
# df['YearsCode'].nunique()

# %%
# we need change 'Less than 1 year' to int
df['YearsCode'].replace('Less than 1 year', 0, inplace = True)
df['YearsCode'].replace('More than 50 years', 51, inplace = True)

# %% [markdown]
# ## df['Col_Name'].astype(int)
# to change data types of values

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.589040005458392

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df['YearsCode'].mode()
# Out:
# 0    5.0
# dtype: float64

# %% [markdown]
# ## Methods for changing column name

# %%
df_pl.columns = ['First_Name','Last_Name' ,'Email_Id']
df_pl
# Out:
#   First_Name Last_Name               Email_Id
# 0      Corey   Schafer  corescha_00@gmail.com
# 1       Jane       Doe    JanaDn_11@gmail.com
# 2       john    Carter   Johncat_22@gmail.com

# %%
df_pl.columns = [x.lower() for x in df_pl.columns]
df_pl
# Out:
#   first_name last_name               email_id
# 0      Corey   Schafer  corescha_00@gmail.com
# 1       Jane       Doe    JanaDn_11@gmail.com
# 2       john    Carter   Johncat_22@gmail.com

# %%
df_pl.columns = df_pl.columns.str.replace('_', ' ')
df_pl
# Out:
#   first name last name               email id
# 0      Corey   Schafer  corescha_00@gmail.com
# 1       Jane       Doe    JanaDn_11@gmail.com
# 2       john    Carter   Johncat_22@gmail.com

# %%
df_pl.rename(columns = {'first name': 'first', 'last name': 'last'}, inplace  = True)
df_pl
# Out:
#    first     last               email id
# 0  Corey  Schafer  corescha_00@gmail.com
# 1   Jane      Doe    JanaDn_11@gmail.com
# 2   john   Carter   Johncat_22@gmail.com

# %% [markdown]
# ### df.set_index('email', inplace = True)

# %%
df_pl.set_index('email id', inplace = True)

# %% [markdown]
# ### df.reset_index(inplace = True)

# %%
df_pl.reset_index(inplace = True)
df_pl
# Out:
#                 email id  first     last
# 0  corescha_00@gmail.com  Corey  Schafer
# 1    JanaDn_11@gmail.com   Jane      Doe
# 2   Johncat_22@gmail.com   john   Carter

# %%
df_pl[(df_pl['last'] == 'Doe')]
# Out:
#               email id first last
# 1  JanaDn_11@gmail.com  Jane  Doe

# %%
df_pl.loc[(df_pl['last'] == 'Doe'), 'first']
# Out:
# 1    Jane
# Name: first, dtype: object

# %% [markdown]
# ### filtering data

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na = False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# ## Changing rows values

# %%
df_pl.loc[2] = [ 'simjame_22@gmail.com','simon','James']
df_pl.at[2, 'last'] = 'Doe'
df_pl
# Out:
#                 email id  first     last
# 0  corescha_00@gmail.com  Corey  Schafer
# 1    JanaDn_11@gmail.com   Jane     NNNN
# 2   simjame_22@gmail.com  simon      Doe

# %%
filt = (df_pl['email id'] == 'JanaDn_11@gmail.com')
df_pl.loc[filt,'last']  = 'walker'
df_pl
# Out:
#                 email id  first     last
# 0  corescha_00@gmail.com  Corey  Schafer
# 1    JanaDn_11@gmail.com   Jane     NNNN
# 2                  James  simon      Doe

# %%
df_pl['email id'] = df_pl['email id'].str.upper()
df_pl
# Out:
#                 email id  first     last
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe

# %% [markdown]
#  ### .apply()

# %%
def update_ml(email):
    return email.lower()
df_pl['email id'] = df_pl['email id'].apply(update_ml)
df_pl
# Out:
#                 email id  first     last
# 0  corescha_00@gmail.com  Corey  Schafer
# 1    janadn_11@gmail.com   Jane     NNNN
# 2   simjame_22@gmail.com  simon      Doe

# %%
df_pl['email id'] = df_pl['email id'].apply(lambda  x : x.upper() )
df_pl
# Out:
#                 email id  first     last
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe

# %%
df_pl.apply(len)
# Out:
# email id    3
# first       3
# last        3
# dtype: int64

# %%
# Equivalent to df.apply(lambda x : x.min())
df_pl.apply(pd.Series.min)
# Out:
# email id    CORESCHA_00@GMAIL.COM
# first                       Corey
# last                          Doe
# dtype: object

# %% [markdown]
# ### .applymap()
# Applies to each individual value

# %%
df_pl.applymap(len)
# Out:
#    email id  first  last
# 0        21      5     7
# 1        19      4     4
# 2        20      5     3

# %%
df_pl.applymap(str.upper)
# Out:
#                 email id  first     last
# 0  CORESCHA_00@GMAIL.COM  COREY  SCHAFER
# 1    JANADN_11@GMAIL.COM   JANE     NNNN
# 2   SIMJAME_22@GMAIL.COM  SIMON      DOE

# %% [markdown]
# ### .map()
# changes all elements in series

# %%
df_pl['first'].map({'Corey': 'chris', 'Jane' : 'Mary'})
# Out:
# 0    chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %% [markdown]
# #### .replace()
# this is best for that doestnt changes previous values

# %%
df_pl['first'].replace({'Corey': 'chris', 'Jane' : 'Mary'})
# Out:
# 0    chris
# 1     Mary
# 2    simon
# Name: first, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes' : True , 'No': False})
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ## Adding and Deleting Columns

# %%
df_pl['full_name'] = df_pl['first'] + ' '+ df_pl['last']
df_pl
# Out:
#                 email id  first     last      full_name
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe

# %% [markdown]
# ### df.drop(columns= '' , inplace = True)

# %%
df_pl.drop(columns = ['first', 'last'])
# Out:
#                 email id      full_name
# 0  CORESCHA_00@GMAIL.COM  Corey Schafer
# 1    JANADN_11@GMAIL.COM      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM      simon Doe

# %% [markdown]
# #### df_pl['full_name'].str.split(' ', expand = True )

# %%
df_pl[['first','last']] = df_pl['full_name'].str.split(' ', expand = True )
df_pl
# Out:
#                 email id  first     last      full_name
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe

# %% [markdown]
# ### df.append( { dict }, ignore_index = True)
#  to add rows

# %%
df_pl = df_pl.append({'first' : 'Tony', 'last': 'stark'}, ignore_index = True )

# %%
pls = { 'first': ['Black'],
        'last' : ['widow']
       }
df2 = pd.DataFrame(pls)
df_pl = df_pl.append(df2, ignore_index = True, sort = False)
df_pl
# Out:
#                 email id  first     last      full_name
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe
# 3                    NaN  Black    widow            NaN
# 4                    NaN   Tony    stark            NaN
# 5                    NaN  Black    widow            NaN

# %% [markdown]
# ### deleting Rows df.drop(index = 5)

# %%
df_pl.drop(index = 5)
# Out:
#                 email id  first     last      full_name
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe
# 3                    NaN  Black    widow            NaN
# 4                    NaN   Tony    stark            NaN

# %%
df_pl.drop(index = (df_pl['last'] == 'NNNN').index)
# Out:
# Empty DataFrame
# Columns: [email id, first, last, full_name]
# Index: []

# %% [markdown]
# # Sorting data
# ### df.sort_values( by = 'colm name', inplace = True)

# %%
df_pl.sort_values(by = 'last' ,ascending = False)
# Out:
#                 email id  first     last      full_name
# 3                    NaN  Black    widow            NaN
# 5                    NaN  Black    widow            NaN
# 4                    NaN   Tony    stark            NaN
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe

# %% [markdown]
# ### df.reindex()

# %%
df_pl.sort_index()
# Out:
#                 email id  first     last      full_name
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe
# 3                    NaN  Black    widow            NaN
# 4                    NaN   Tony    stark            NaN
# 5                    NaN  Black    widow            NaN

# %%
df.sort_values(by = ['Country','ConvertedComp'] ,ascending = [True, False], inplace = True)
# salaries in decesding order

df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 722         Afghanistan            0.0
# 28638       Afghanistan            0.0
# 6417        Afghanistan            NaN
# 7353        Afghanistan            NaN
# 12310       Afghanistan            NaN
# 26340       Afghanistan            NaN
# 29045       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 37802       Afghanistan            NaN
# 40000       Afghanistan            NaN
# 43106       Afghanistan            NaN
# 44403       Afghanistan            NaN
# 45854       Afghanistan            NaN
# ...

# %%
df.sort_values(by = ['last','first'] ,ascending =[ False,True])
# Out:
#                 email id  first     last      full_name
# 3                    NaN  Black    widow            NaN
# 5                    NaN  Black    widow            NaN
# 4                    NaN   Tony    stark            NaN
# 0  CORESCHA_00@GMAIL.COM  Corey  Schafer  Corey Schafer
# 1    JANADN_11@GMAIL.COM   Jane     NNNN      Jane NNNN
# 2   SIMJAME_22@GMAIL.COM  simon      Doe      simon Doe

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# ...

# %%
df.nsmallest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 280         I am a developer by profession      Yes
# 293         I am a developer by profession      Yes
# 722         I am a developer by profession       No
# 1105        I am a developer by profession       No
# 1501        I am a developer by profession      Yes
# 1685        I am a developer by profession      Yes
# 1782        I am a developer by profession      Yes
# 2019        I am a developer by profession       No
# 2095        I am a developer by profession      Yes
# 2665        I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 280                                   Less than once per year
# 293                                   Less than once per year
# 722         Less than once a month but more than once per ...
# 1105                                                    Never
# ...

# %% [markdown]
# ## Grouping and Aggregating

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_5220\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize = True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %% [markdown]
# # spliting , apply function, combining [group by operation ]

# %%
country_grp = df.groupby(['Country'])
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
# for india
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize = True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
 # this doesnot work , it need .apply()
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <module>
#       1 # this doesnot work , it need .apply()
# ----> 2 country_grp['LanguageWorkedWith'].str.contains('Python').apply(sum)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:911, in GroupBy.__getattr__(self, attr)
#     908 if attr in self.obj:
#     909     return self[attr]
# --> 911 raise AttributeError(
#     912     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum()).loc['India']
# Out:
# 3105

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python], axis = 'columns')
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns= {'Country' : 'NumRespondensts', 'LangaugeWorkedWith': 'NumKnowsPython'}, inplace = True)

# %%
python_df
# Out:
#                    NumRespondensts  LanguageWorkedWith
# United States                20949               10083
# India                         9061                3105
# Germany                       5866                2451
# United Kingdom                5737                2384
# Canada                        3395                1558
# ...                            ...                 ...
# Tonga                            1                   0
# Timor-Leste                      1                   1
# North Korea                      1                   0
# Brunei Darussalam                1                   0
# Chad                             1                   0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumRespondensts']/python_df['LanguageWorkedWith']) *100

# %%
python_df
# Out:
#                    NumRespondensts  LanguageWorkedWith  PctKnowsPython
# United States                20949               10083      207.765546
# India                         9061                3105      291.819646
# Germany                       5866                2451      239.330885
# United Kingdom                5737                2384      240.645973
# Canada                        3395                1558      217.907574
# ...                            ...                 ...             ...
# Tonga                            1                   0             inf
# Timor-Leste                      1                   1      100.000000
# North Korea                      1                   0             inf
# Brunei Darussalam                1                   0             inf
# Chad                             1                   0             inf
#
# [179 rows x 3 columns]

# %% [markdown]
# # Cleaning Data , Missing Valuess

# %%
people = {
    'first' : ['Corey', 'Jane' , 'john','Chris', np.nan, None, 'NA'],
    'last' :['Schafer', "Doe", "Carter", 'Schafer', np.nan, np.nan, 'Missing'],
    'email' : ['Corescha_00@gmail.com' , 'JaneDoe_11@gmail.com', 'Johncat_22@gmail.com', None, np.nan, 'Anonymous@gmail.com','NA'],
    'age': ['33','55','63','36', None,None,'Missing']
}
df = pd.DataFrame(people)
df.replace('NA', np.nan , inplace = True)
df.replace('Missing', np.nan , inplace = True)
df
# Out:
#    first     last                  email   age
# 0  Corey  Schafer  Corescha_00@gmail.com    33
# 1   Jane      Doe   JaneDoe_11@gmail.com    55
# 2   john   Carter   Johncat_22@gmail.com    63
# 3  Chris  Schafer                   None    36
# 4    NaN      NaN                    NaN  None
# 5   None      NaN    Anonymous@gmail.com  None
# 6    NaN      NaN                    NaN   NaN

# %%
# dropna() will delete rows with NaN value.
df.dropna()
# Out:
#    first     last                  email age
# 0  Corey  Schafer  Corescha_00@gmail.com  33
# 1   Jane      Doe   JaneDoe_11@gmail.com  55
# 2   john   Carter   Johncat_22@gmail.com  63

# %%
df.dropna(axis = 'index', how = 'any')
# Out:
#    first     last                  email      age
# 0  Corey  Schafer  Corescha_00@gmail.com       33
# 1   Jane      Doe   JaneDoe_11@gmail.com       55
# 2   john   Carter   Johncat_22@gmail.com       63
# 6     NA  Missing                     NA  Missing

# %%
df.dropna(axis = 'index', how = 'all')
# Out:
#    first     last                  email      age
# 0  Corey  Schafer  Corescha_00@gmail.com       33
# 1   Jane      Doe   JaneDoe_11@gmail.com       55
# 2   john   Carter   Johncat_22@gmail.com       63
# 3  Chris  Schafer                   None       36
# 5   None      NaN    Anonymous@gmail.com     None
# 6     NA  Missing                     NA  Missing

# %%
df.dropna(axis = 'index', how = 'any', subset = ['email'])
# Out:
#    first     last                  email      age
# 0  Corey  Schafer  Corescha_00@gmail.com       33
# 1   Jane      Doe   JaneDoe_11@gmail.com       55
# 2   john   Carter   Johncat_22@gmail.com       63
# 5   None      NaN    Anonymous@gmail.com     None
# 6     NA  Missing                     NA  Missing

# %%
df.dropna(axis = 'index', how = 'all', subset = ['last','email'])
# Out:
#    first     last                  email   age
# 0  Corey  Schafer  Corescha_00@gmail.com    33
# 1   Jane      Doe   JaneDoe_11@gmail.com    55
# 2   john   Carter   Johncat_22@gmail.com    63
# 3  Chris  Schafer                   None    36
# 5   None      NaN    Anonymous@gmail.com  None

# %% [markdown]
# ### deleting Columns

# %%
df.dropna(axis = 'columns', how = 'any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### df.isna() : to check null or not

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %% [markdown]
# ### df.fillna('Miss')

# %%
df.fillna(0, inplace = True)

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age       int32
# Age      object
# dtype: object

# %%
df['age'] = df['age'].astype(int)
df
# Out:
#    first     last                  email  age   Age
# 0  Corey  Schafer  Corescha_00@gmail.com   33    33
# 1   Jane      Doe   JaneDoe_11@gmail.com   55    55
# 2   john   Carter   Johncat_22@gmail.com   63    63
# 3  Chris  Schafer                      0   36    36
# 4      0        0                      0    0  None
# 5      0        0    Anonymous@gmail.com    0  None
# 6      0        0                      0    0   nan

# %%
# cannt calculate mean if it have NaN values
df['age'].mean()
# Out:
# 26.714285714285715

# %% [markdown]
# ### Changing missing values while read csv
# na_v = [ 'na','Missing']
# #### df = pd.read_csv('f/Location', na_values = na_v)

# %%
# pd.cut()

# %%
import pandas as pd

df = pd.DataFrame({'age' : [25,30,35,40,45,55]})

bins = [20,30,40,50]


labels = ['Young', 'Middle Aged', 'senior']

df['age_group'] = pd.cut(df['age'] , 
                        bins = bins,
                        labels = labels,
                        right = False)

df
# Out:
#    age    age_group
# 0   25        Young
# 1   30  Middle Aged
# 2   35  Middle Aged
# 3   40       senior
# 4   45       senior
# 5   55          NaN

# %% [markdown]
# ## df.pivot

# %%
# Load the financial data into a DataFrame
data = {'Month': ['Jan', 'Jan', 'Jan', 'Feb', 'Feb', 'Feb', 'Mar', 'Mar', 'Mar'],
        'Year': [2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020],
        'Expense Type': ['Rent', 'Food', 'Transportation', 'Rent', 'Food', 'Transportation', 'Rent', 'Food', 'Transportation'],
        'Expense Amount': [1000, 500, 200, 900, 400, 150, 800, 450, 175]}
df = pd.DataFrame(data)
df
# Out:
#   Month  Year    Expense Type  Expense Amount
# 0   Jan  2020            Rent            1000
# 1   Jan  2020            Food             500
# 2   Jan  2020  Transportation             200
# 3   Feb  2020            Rent             900
# 4   Feb  2020            Food             400
# 5   Feb  2020  Transportation             150
# 6   Mar  2020            Rent             800
# 7   Mar  2020            Food             450
# 8   Mar  2020  Transportation             175

# %%
import pandas as pd
import numpy as np

# Create a sample dataframe
df = pd.DataFrame({'marks': [80, 85, 90, 95, 100]})

# Cut the 'marks' column into 4 bins
df['marks_group'] = pd.cut(df['marks'], bins=4, labels=False)

# Assign custom labels to the bins
df['marks_group'] = 'Group ' + (df['marks_group'] + 1).astype(str)

df
# Out:
#    marks marks_group
# 0     80     Group 1
# 1     85     Group 1
# 2     90     Group 2
# 3     95     Group 3
# 4    100     Group 4

# %% [markdown]
# ## pd.merge() , pd.concat()

# %%
import pandas as pd

# First dataset
sales_data1 = {
    'Product ID': [1, 2, 3, 4, 5],
    'Product Name': ['Laptop', 'Smartphone', 'Tablet', 'Printer', 'Monitor'],
    'Sales Quantity': [10, 15, 20, 5, 12],
    'Revenue': [1000, 1500, 2000, 500, 1200]
}

df1 = pd.DataFrame(sales_data1)

# Second dataset
sales_data2 = {
    'Product ID': [1, 2, 4, 6, 7],
    'Region': ['North', 'South', 'West', 'East', 'North'],
    'Discount': [0.1, 0.15, 0.05, 0.05, 0.2]
}

df2 = pd.DataFrame(sales_data2)

# Merge the two datasets based on "Product ID"
merged_sales_data = pd.merge(df1, df2, on='Product ID')
merged_sales_data
# Out:
#    Product ID Product Name  Sales Quantity  Revenue Region  Discount
# 0           1       Laptop              10     1000  North      0.10
# 1           2   Smartphone              15     1500  South      0.15
# 2           4      Printer               5      500   West      0.05

# %%
import pandas as pd

# Create two sample dataframes
df1 = pd.DataFrame({'Month': ['Jan', 'Feb', 'Mar'],
                    'Sales': [1000, 2000, 3000]})

df2 = pd.DataFrame({'Month': ['Apr', 'May', 'June'],
                    'Expenses': [100, 200, 300]})

# Concatenate the two dataframes
result = pd.concat([df1, df2], axis=1)

(result)
# Out:
#   Month  Sales Month  Expenses
# 0   Jan   1000   Apr       100
# 1   Feb   2000   May       200
# 2   Mar   3000  June       300

# %%
import pandas as pd

# Create two sample dataframes
df1 = pd.DataFrame({'Month': ['Jan', 'Feb', 'Mar'],
                    'Sales': [1000, 2000, 3000]})

df2 = pd.DataFrame({'Month': ['Apr', 'May', 'Jun'],
                    'Sales': [4000, 5000, 6000]})

# Concatenate the two dataframes
result = pd.concat([df1, df2], axis = 0)

(result)
# Out:
#   Month  Sales
# 0   Jan   1000
# 1   Feb   2000
# 2   Mar   3000
# 0   Apr   4000
# 1   May   5000
# 2   Jun   6000

# %% [markdown]
# ## pd.get_dummies(df, columns  = '')

# %%
import pandas as pd

# Sample data with categorical variables
data = {'fruit': ['apple', 'banana', 'orange', 'banana', 'apple', 'orange']}

# Create a dataframe from the sample data
df = pd.DataFrame(data)

# Perform one hot encoding on the 'fruit' column
df = pd.get_dummies(df, columns=['fruit'])

# Check the resulting dataframe
(df)
# Out:
#    fruit_apple  fruit_banana  fruit_orange
# 0            1             0             0
# 1            0             1             0
# 2            0             0             1
# 3            0             1             0
# 4            1             0             0
# 5            0             0             1

# %%
# List of nested dictionary initialization
list = [
        {
        "Student": [{"Exam": 90, "Grade": "a"},
                    {"Exam": 99, "Grade": "b"},
                    {"Exam": 97, "Grade": "c"},
                   ],
        "Name": "Paras Jain"
        },
        {
        "Student": [{"Exam": 89, "Grade": "a"},
                    {"Exam": 80, "Grade": "b"}
                   ],
        "Name": "Chunky Pandey"
        }
       ]
print(list)

# rows list initialization
rows = []  
# appending rows
for data in list:
    data_row = data['Student']
    time = data['Name']
    for row in data_row:
        row['Name']= time
        rows.append(row) 

# using data frame
df = pd.DataFrame(rows)
df
# Out:
# [{'Student': [{'Exam': 90, 'Grade': 'a'}, {'Exam': 99, 'Grade': 'b'}, {'Exam': 97, 'Grade': 'c'}], 'Name': 'Paras Jain'}, {'Student': [{'Exam': 89, 'Grade': 'a'}, {'Exam': 80, 'Grade': 'b'}], 'Name': 'Chunky Pandey'}]
#    Exam Grade           Name
# 0    90     a     Paras Jain
# 1    99     b     Paras Jain
# 2    97     c     Paras Jain
# 3    89     a  Chunky Pandey
# 4    80     b  Chunky Pandey

# %%
import pandas as pd
# Create the dataframe
df = pd.DataFrame({'Date':['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
                   'Product':[' UMbreLla', '  maTress', 'BaDmintoN ', 'Shuttle'],
                   'Updated_Price':[1250, 1450, 1550, 400],
                   'Discount':[10, 8, 15, 10]})
  
# Print the dataframe
print(df)
# Out:
#         Date     Product  Updated_Price  Discount
# 0  10/2/2011    UMbreLla           1250        10
# 1  11/2/2011     maTress           1450         8
# 2  12/2/2011  BaDmintoN            1550        15
# 3  13/2/2011     Shuttle            400        10

# %%
def Format_date(df):
    for i in range(df.shape[0]):
        df.iat[i,1] = df.iat[i,1].strip().capitalize()
        
Format_date(df)

print(df)
# Out:
#         Date    Product  Updated_Price  Discount
# 0  10/2/2011   Umbrella           1250        10
# 1  11/2/2011    Matress           1450         8
# 2  12/2/2011  Badminton           1550        15
# 3  13/2/2011    Shuttle            400        10

# %%
import pandas as pd
 
# import the StrinIO function
# from io module
from io import StringIO


# wrap the string data in StringIO function
StringData = StringIO("""Date;Event;Cost
    10/2/2011;Music;10000
    11/2/2011;Poetry;12000
    12/2/2011;Theatre;5000
    13/2/2011;Comedy;8000
    """)
 
    
# let's read the data using the Pandas
# read_csv() function
df = pd.read_csv(StringData, sep =";")

# Print the dataframe
(df)
# Out:
#             Date    Event   Cost
# 0      10/2/2011    Music  10000
# 1      11/2/2011   Poetry  12000
# 2      12/2/2011  Theatre   5000
# 3      13/2/2011   Comedy   8000

# %%
column = ['a', 'b', 'c', 'd','e', ]
index = [i.upper() for i in column ]

df1 = pd.DataFrame(np.random.rand(5,5), columns = column , index= index)
df.reindex()

df1
# Out:
#           a         b         c         d         e
# A  0.411610  0.050207  0.155331  0.544880  0.970110
# B  0.404758  0.498508  0.509869  0.224841  0.854736
# C  0.047926  0.956285  0.258195  0.680910  0.417070
# D  0.387025  0.017476  0.132229  0.500009  0.480365
# E  0.019501  0.952991  0.771635  0.546086  0.562483

# %%
# Python3 program to demonstrate the use of
# strip() method 
 
string = """    geeks for geeks    """
 
# prints the string without stripping
print(string)
 
# prints the string by removing leading and trailing whitespaces
print(string.strip())  
 
# prints the string by removing geeks
print(string.strip(' geeks'))
# Out:
#     geeks for geeks
# geeks for geeks
# for

# %%
# Python Program to demonstrate use of strip() method
 
str1 = 'geeks for geeks'
# Print the string without stripping.
print(str1)
 
# String whose set of characters are to be
# remove from original string at both its ends.
str2 = 'ekgs'

# Print string after stripping str2 from str1 at both its end.
print(str1.strip(str2))
# Out:
# geeks for geeks
#  for

# %% [markdown]
# Pandas Drop Duplicates
# We will run through 3 examples:
#
# Dropping rows from duplicate rows
# Dropping rows from duplicate subset of columns
# Keeping the last duplicate instead of the default first column
# Let's create our DataFrame

# %%
df = pd.DataFrame({
    'brand': ['Jet Boil', 'Jet Boil', 'Osprey', 'Osprey', 'Osprey'],
    'equipment': ['Stove', 'Stove', 'Backpack', 'Waterbottle', 'Backpack'],
    'rating': [3, 3, 5.5, 8.6, 7]
})
df
# Out:
#       brand    equipment  rating
# 0  Jet Boil        Stove     3.0
# 1  Jet Boil        Stove     3.0
# 2    Osprey     Backpack     5.5
# 3    Osprey  Waterbottle     8.6
# 4    Osprey     Backpack     7.0

# %% [markdown]
# ### 1. Dropping rows from duplicate rows
# When we call the default drop_duplicates, we are asking pandas to find all the duplicate rows, and then keep only the first ones.
#
# Notice below, we call drop duplicates and row 2 (index=1) gets dropped because is the 2nd instance of a duplicate row.

# %%
df.drop_duplicates()
# Out:
#       brand    equipment  rating
# 0  Jet Boil        Stove     3.0
# 2    Osprey     Backpack     5.5
# 3    Osprey  Waterbottle     8.6
# 4    Osprey     Backpack     7.0

# %% [markdown]
# ### 2. Dropping rows from duplicate subset of columns
# When we specify a subset of column, drop duplicates will only look at a column (or mutiple columns) to see if they are duplicates with any other subset of columns from othr rows. If so, then those duplicates will get dropped.
#
# Here we are specifying a subset to only look at the column 'brand.' All duplicates within the brand column will get dropped except for the 1st ones (because keep defaults to 'first').

# %%
df.drop_duplicates(subset='brand')
# Out:
#       brand equipment  rating
# 0  Jet Boil     Stove     3.0
# 2    Osprey  Backpack     5.5

# %%
# You can also do multiple columns as a subset by passing a list
df.drop_duplicates(subset=['brand', 'equipment'])
# Out:
#       brand    equipment  rating
# 0  Jet Boil        Stove     3.0
# 2    Osprey     Backpack     5.5
# 3    Osprey  Waterbottle     8.6

# %% [markdown]
# ### 3. Keeping the last duplicate instead of the default first
# By default, .drop_duplicates() will keep your first duplicate it finds. However, if you wanted to switch it up and keep the last one you can specify keep='last'
#
# Here we are running the same command as the first example, but keep='last'. Notice how row 1 (index=0) gets dropped. We keep the last duplicate only.

# %%
df.drop_duplicates(keep='last')
# Out:
#       brand    equipment  rating
# 1  Jet Boil        Stove     3.0
# 2    Osprey     Backpack     5.5
# 3    Osprey  Waterbottle     8.6
# 4    Osprey     Backpack     7.0
